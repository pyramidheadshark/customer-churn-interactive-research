# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib
import warnings

# %%
import lightgbm as lgb
import optuna
from optuna.integration import LightGBMPruningCallback

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    roc_auc_score,
    f1_score,
    recall_score,
    precision_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    RocCurveDisplay,
    PrecisionRecallDisplay,
    average_precision_score
)

# %%
warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    message="The reported value is ignored because"
)

# %%
DATA_DIR = '../data/processed/'
X_TRAIN_PATH = os.path.join(DATA_DIR, 'X_train_processed.csv')
X_TEST_PATH = os.path.join(DATA_DIR, 'X_test_processed.csv')
Y_TRAIN_PATH = os.path.join(DATA_DIR, 'y_train.csv')
Y_TEST_PATH = os.path.join(DATA_DIR, 'y_test.csv')

# %%
OPTUNA_DB_URL = 'sqlite:///optuna_lgbm_churn.db'
STUDY_NAME = 'lgbm_churn_optimization_v1'
N_TRIALS = 1000
N_SPLITS_CV = 5
EARLY_STOPPING_ROUNDS = 50
RANDOM_SEED = 42

# %%
MODEL_DIR = '../models/'
os.makedirs(MODEL_DIR, exist_ok=True)
MODEL_PATH = os.path.join(MODEL_DIR, 'lgbm_churn_model.joblib')

# %%
print("--- Загрузка обработанных данных ---")
try:
    X_train = pd.read_csv(X_TRAIN_PATH)
    X_test = pd.read_csv(X_TEST_PATH)
    y_train = pd.read_csv(Y_TRAIN_PATH).squeeze('columns')
    y_test = pd.read_csv(Y_TEST_PATH).squeeze('columns')

    if not isinstance(y_train, pd.Series):
        y_train = y_train[y_train.columns[0]]
    if not isinstance(y_test, pd.Series):
        y_test = y_test[y_test.columns[0]]

    print("Данные успешно загружены.")
    print(f"Размер X_train: {X_train.shape}")
    print(f"Размер X_test: {X_test.shape}")
    print(f"Тип y_train: {type(y_train)}")

except FileNotFoundError as e:
    print(f"Ошибка: Не найден файл. Проверьте пути. {e}")
except Exception as e:
    print(f"Произошла ошибка при загрузке данных: {e}")
# Out:
# --- Загрузка обработанных данных ---
# Данные успешно загружены.
# Размер X_train: (8000, 14)
# Размер X_test: (2000, 14)
# Тип y_train: <class 'pandas.core.series.Series'>

# %%
def evaluate_model(model, X_test, y_test, model_name="Model"):
    """Оценивает модель и выводит основные метрики."""
    print(f"\n--- Оценка модели: {model_name} ---")
    try:
        if hasattr(model, "predict_proba"):
            y_pred_proba = model.predict_proba(X_test)[:, 1]
            roc_auc = roc_auc_score(y_test, y_pred_proba)
            pr_auc = average_precision_score(y_test, y_pred_proba)
            print(f"ROC AUC: {roc_auc:.4f}")
            print(f"PR AUC (Average Precision): {pr_auc:.4f}")
        else:
            y_pred_proba = None
            roc_auc = None
            pr_auc = None
            
            print("ROC AUC / PR AUC не могут быть посчитаны.")

        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred, pos_label=1, zero_division=0)
        recall = recall_score(y_test, y_pred, pos_label=1, zero_division=0)
        precision = precision_score(y_test, y_pred, pos_label=1, zero_division=0)

        print(f"F1 Score (Class 1): {f1:.4f}")
        print(f"Recall (Class 1): {recall:.4f}")
        print(f"Precision (Class 1): {precision:.4f}")
        print("\nClassification Report:")
        print(classification_report(y_test, y_pred, target_names=['Лоялен (0)', 'Отток (1)'], zero_division=0))
        print("Confusion Matrix:")
        cm = confusion_matrix(y_test, y_pred)
        print(cm)
        
        return {'roc_auc': roc_auc, 'f1_score_1': f1, 'recall_1': recall, 'precision_1': precision, 'pr_auc': pr_auc}
    
    except Exception as e:
        print(f"Ошибка при оценке модели {model_name}: {e}")
        return None

# %%
def objective(trial):
    """Функция, которую Optuna будет минимизировать/максимизировать."""
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'boosting_type': 'gbdt',
        'n_estimators': trial.suggest_int('n_estimators', 500, 6000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.03, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 10, 80),
        'max_depth': trial.suggest_int('max_depth', 2, 7),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 7),
        'min_child_samples': trial.suggest_int('min_child_samples', 20, 150),
        'class_weight': 'balanced',
        'random_state': RANDOM_SEED,
        'n_jobs': -1,
        'verbose': -1
    }

    cv = StratifiedKFold(n_splits=N_SPLITS_CV, shuffle=True, random_state=RANDOM_SEED)
    cv_scores = []

    for fold, (train_idx, val_idx) in enumerate(cv.split(X_train, y_train)):
        X_train_fold, X_val_fold = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_train_fold, y_val_fold = y_train.iloc[train_idx], y_train.iloc[val_idx]

        pruning_callback = LightGBMPruningCallback(trial, 'auc')

        model = lgb.LGBMClassifier(**params)
        try:
            model.fit(X_train_fold, y_train_fold,
                      eval_set=[(X_val_fold, y_val_fold)],
                      eval_metric='auc',
                      callbacks=[lgb.early_stopping(EARLY_STOPPING_ROUNDS, verbose=False),
                                 pruning_callback]
                     )
            preds_proba = model.predict_proba(X_val_fold)[:, 1]
            fold_auc = roc_auc_score(y_val_fold, preds_proba)
            cv_scores.append(fold_auc)
        except optuna.TrialPruned as e:
             raise e
        except Exception as e:
            print(f"Ошибка в Trial {trial.number}, Fold {fold}: {e}")
            return 0.0

    if not cv_scores:
        return 0.0

    mean_auc = np.mean(cv_scores)
    return mean_auc

# %%
print(f"\n--- Запуск Optuna для исследования '{STUDY_NAME}' ---")
print(f"Хранилище: {OPTUNA_DB_URL}")
print(f"Количество испытаний: {N_TRIALS}")
print(f"Количество фолдов CV: {N_SPLITS_CV}")
print(f"Метрика оптимизации: ROC AUC (Maximize)")

storage = optuna.storages.RDBStorage(url=OPTUNA_DB_URL)

study = optuna.create_study(
    storage=storage,
    study_name=STUDY_NAME,
    direction='maximize',
    load_if_exists=True
)

try:
    study.optimize(objective, n_trials=N_TRIALS, timeout=None)
except KeyboardInterrupt:
    print("Оптимизация прервана пользователем.")
# Out:
# --- Запуск Optuna для исследования 'lgbm_churn_optimization_v1' ---
# Хранилище: sqlite:///optuna_lgbm_churn.db
# Количество испытаний: 1000
# Количество фолдов CV: 5
# Метрика оптимизации: ROC AUC (Maximize)
# [I 2025-03-26 17:03:41,911] A new study created in RDB with name: lgbm_churn_optimization_v1
# [I 2025-03-26 17:04:13,674] Trial 0 finished with value: 0.8636621047663994 and parameters: {'n_estimators': 3400, 'learning_rate': 0.014167679979322917, 'num_leaves': 20, 'max_depth': 6, 'reg_alpha': 0.2560838647562468, 'reg_lambda': 0.012980554682202477, 'colsample_bytree': 0.9810306059256777, 'subsample': 0.6160566256653015, 'subsample_freq': 3, 'min_child_samples': 69}. Best is trial 0 with value: 0.8636621047663994.
# [I 2025-03-26 17:05:44,937] Trial 1 finished with value: 0.8615018636052817 and parameters: {'n_estimators': 5600, 'learning_rate': 0.021415437040384924, 'num_leaves': 70, 'max_depth': 2, 'reg_alpha': 0.41094741485257963, 'reg_lambda': 6.522994159748028, 'colsample_bytree': 0.7602407786445065, 'subsample': 0.8621636193160056, 'subsample_freq': 1, 'min_child_samples': 120}. Best is trial 0 with value: 0.8636621047663994.
# [I 2025-03-26 17:06:36,408] Trial 2 finished with value: 0.8622020398532229 and parameters: {'n_estimators': 4200, 'learning_rate': 0.006484911708266083, 'num_leaves': 20, 'max_depth': 6, 'reg_alpha': 0.00481648925906801, 'reg_lambda': 0.3183604910913093, 'colsample_bytree': 0.5826227329670798, 'subsample': 0.8719257045515392, 'subsample_freq': 4, 'min_child_samples': 69}. Best is trial 0 with value: 0.8636621047663994.
# [I 2025-03-26 17:07:10,339] Trial 3 finished with value: 0.8629703556741243 and parameters: {'n_estimators': 1700, 'learning_rate': 0.0072447056764236226, 'num_leaves': 39, 'max_depth': 7, 'reg_alpha': 0.9028976878784729, 'reg_lambda': 0.6112832578851285, 'colsample_bytree': 0.41622172356649556, 'subsample': 0.8447043323866767, 'subsample_freq': 2, 'min_child_samples': 20}. Best is trial 0 with value: 0.8636621047663994.
# [I 2025-03-26 17:07:38,195] Trial 4 finished with value: 0.865180437441612 and parameters: {'n_estimators': 1100, 'learning_rate': 0.02036801191353118, 'num_leaves': 33, 'max_depth': 4, 'reg_alpha': 0.0010435915953760136, 'reg_lambda': 0.04489007362027578, 'colsample_bytree': 0.9523386164400685, 'subsample': 0.6957171970288996, 'subsample_freq': 5, 'min_child_samples': 51}. Best is trial 4 with value: 0.865180437441612.
# [I 2025-03-26 17:07:38,334] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:38,433] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:38,522] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:40,110] Trial 8 pruned. Trial was pruned at iteration 95.
# [I 2025-03-26 17:07:40,199] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:40,329] Trial 10 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:40,504] Trial 11 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:07:40,677] Trial 12 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:07:41,873] Trial 13 pruned. Trial was pruned at iteration 59.
# [I 2025-03-26 17:07:57,453] Trial 14 finished with value: 0.8620929683813119 and parameters: {'n_estimators': 1600, 'learning_rate': 0.018866709342229025, 'num_leaves': 54, 'max_depth': 7, 'reg_alpha': 0.01825067477454973, 'reg_lambda': 0.003274192793650219, 'colsample_bytree': 0.6637786089679851, 'subsample': 0.472886031509946, 'subsample_freq': 7, 'min_child_samples': 89}. Best is trial 4 with value: 0.865180437441612.
# [I 2025-03-26 17:07:57,661] Trial 15 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:57,910] Trial 16 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:07:58,101] Trial 17 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:07:58,322] Trial 18 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:02,392] Trial 19 pruned. Trial was pruned at iteration 181.
# [I 2025-03-26 17:08:02,565] Trial 20 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:08:02,725] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:06,447] Trial 22 pruned. Trial was pruned at iteration 160.
# [I 2025-03-26 17:08:14,676] Trial 23 pruned. Trial was pruned at iteration 299.
# [I 2025-03-26 17:08:14,950] Trial 24 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:15,106] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:15,800] Trial 26 pruned. Trial was pruned at iteration 32.
# [I 2025-03-26 17:08:16,503] Trial 27 pruned. Trial was pruned at iteration 32.
# [I 2025-03-26 17:08:18,841] Trial 28 pruned. Trial was pruned at iteration 102.
# [I 2025-03-26 17:08:19,006] Trial 29 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:19,167] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:19,439] Trial 31 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:19,627] Trial 32 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:19,804] Trial 33 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:08:19,959] Trial 34 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:20,122] Trial 35 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:20,294] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:20,463] Trial 37 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:20,646] Trial 38 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:08:20,860] Trial 39 pruned. Trial was pruned at iteration 2.
# [I 2025-03-26 17:08:21,066] Trial 40 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:08:21,232] Trial 41 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:21,420] Trial 42 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:23,756] Trial 43 pruned. Trial was pruned at iteration 102.
# [I 2025-03-26 17:08:24,027] Trial 44 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:24,564] Trial 45 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:08:24,779] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:38,900] Trial 47 finished with value: 0.8627921815257485 and parameters: {'n_estimators': 800, 'learning_rate': 0.0225652531558831, 'num_leaves': 57, 'max_depth': 7, 'reg_alpha': 0.0075227865543644095, 'reg_lambda': 0.010757206833520237, 'colsample_bytree': 0.8027367456837257, 'subsample': 0.5398494280882957, 'subsample_freq': 5, 'min_child_samples': 60}. Best is trial 4 with value: 0.865180437441612.
# [I 2025-03-26 17:08:39,111] Trial 48 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:39,251] Trial 49 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:39,465] Trial 50 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:39,713] Trial 51 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:08:39,884] Trial 52 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:40,019] Trial 53 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:40,741] Trial 54 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:08:40,879] Trial 55 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:41,038] Trial 56 pruned. Trial was pruned at iteration 2.
# [I 2025-03-26 17:08:42,290] Trial 57 pruned. Trial was pruned at iteration 59.
# [I 2025-03-26 17:08:42,432] Trial 58 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:08:55,249] Trial 59 finished with value: 0.8633551155242654 and parameters: {'n_estimators': 3500, 'learning_rate': 0.026387306494651427, 'num_leaves': 67, 'max_depth': 7, 'reg_alpha': 0.1090007446707134, 'reg_lambda': 0.3614586604657623, 'colsample_bytree': 0.8116919155764666, 'subsample': 0.7905651031128114, 'subsample_freq': 1, 'min_child_samples': 46}. Best is trial 4 with value: 0.865180437441612.
# [I 2025-03-26 17:08:56,652] Trial 60 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:08:58,732] Trial 61 pruned. Trial was pruned at iteration 110.
# [I 2025-03-26 17:08:59,810] Trial 62 pruned. Trial was pruned at iteration 63.
# [I 2025-03-26 17:09:00,106] Trial 63 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:00,860] Trial 64 pruned. Trial was pruned at iteration 38.
# [I 2025-03-26 17:09:01,016] Trial 65 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:01,154] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:01,288] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:01,421] Trial 68 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:01,620] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:09:01,791] Trial 70 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:01,921] Trial 71 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:02,054] Trial 72 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:02,208] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:02,410] Trial 74 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:03,048] Trial 75 pruned. Trial was pruned at iteration 36.
# [I 2025-03-26 17:09:03,183] Trial 76 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:03,322] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:03,452] Trial 78 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:03,703] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:03,836] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:04,004] Trial 81 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:04,798] Trial 82 pruned. Trial was pruned at iteration 35.
# [I 2025-03-26 17:09:04,936] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:05,067] Trial 84 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:05,770] Trial 85 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:09:05,902] Trial 86 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:06,124] Trial 87 pruned. Trial was pruned at iteration 7.
# [I 2025-03-26 17:09:06,257] Trial 88 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:06,475] Trial 89 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:09:06,614] Trial 90 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:06,826] Trial 91 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:09:07,159] Trial 92 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:09:07,345] Trial 93 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:07,499] Trial 94 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:09:08,539] Trial 95 pruned. Trial was pruned at iteration 61.
# [I 2025-03-26 17:09:08,678] Trial 96 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:08,859] Trial 97 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:09,225] Trial 98 pruned. Trial was pruned at iteration 3.
# [I 2025-03-26 17:09:09,362] Trial 99 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:09,502] Trial 100 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:12,113] Trial 101 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:09:13,493] Trial 102 pruned. Trial was pruned at iteration 77.
# [I 2025-03-26 17:09:13,678] Trial 103 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:13,889] Trial 104 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:09:20,994] Trial 105 pruned. Trial was pruned at iteration 299.
# [I 2025-03-26 17:09:28,040] Trial 106 pruned. Trial was pruned at iteration 299.
# [I 2025-03-26 17:09:30,741] Trial 107 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:09:30,901] Trial 108 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:33,363] Trial 109 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:09:34,600] Trial 110 pruned. Trial was pruned at iteration 56.
# [I 2025-03-26 17:09:37,369] Trial 111 pruned. Trial was pruned at iteration 147.
# [I 2025-03-26 17:09:39,869] Trial 112 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:09:40,026] Trial 113 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:09:40,167] Trial 114 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:41,130] Trial 115 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:09:41,276] Trial 116 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:41,422] Trial 117 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:41,559] Trial 118 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:41,698] Trial 119 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:42,400] Trial 120 pruned. Trial was pruned at iteration 36.
# [I 2025-03-26 17:09:42,543] Trial 121 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:43,958] Trial 122 pruned. Trial was pruned at iteration 77.
# [I 2025-03-26 17:09:44,097] Trial 123 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:46,172] Trial 124 pruned. Trial was pruned at iteration 106.
# [I 2025-03-26 17:09:46,879] Trial 125 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:09:47,022] Trial 126 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:48,208] Trial 127 pruned. Trial was pruned at iteration 56.
# [I 2025-03-26 17:09:49,535] Trial 128 pruned. Trial was pruned at iteration 79.
# [I 2025-03-26 17:09:52,517] Trial 129 pruned. Trial was pruned at iteration 160.
# [I 2025-03-26 17:09:53,831] Trial 130 pruned. Trial was pruned at iteration 77.
# [I 2025-03-26 17:09:53,974] Trial 131 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:55,235] Trial 132 pruned. Trial was pruned at iteration 65.
# [I 2025-03-26 17:09:56,074] Trial 133 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:09:56,213] Trial 134 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:09:57,076] Trial 135 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:10:16,162] Trial 136 finished with value: 0.8653692057285397 and parameters: {'n_estimators': 4400, 'learning_rate': 0.0231336496056604, 'num_leaves': 21, 'max_depth': 7, 'reg_alpha': 0.013084385071543842, 'reg_lambda': 0.40470051985952027, 'colsample_bytree': 0.7837665479281083, 'subsample': 0.8341784879213847, 'subsample_freq': 4, 'min_child_samples': 34}. Best is trial 136 with value: 0.8653692057285397.
# [I 2025-03-26 17:10:16,352] Trial 137 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:16,534] Trial 138 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:19,488] Trial 139 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:19,705] Trial 140 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:10:22,257] Trial 141 pruned. Trial was pruned at iteration 107.
# [I 2025-03-26 17:10:22,445] Trial 142 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:22,879] Trial 143 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:10:23,072] Trial 144 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:23,257] Trial 145 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:23,672] Trial 146 pruned. Trial was pruned at iteration 12.
# [I 2025-03-26 17:10:23,883] Trial 147 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:24,057] Trial 148 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:24,326] Trial 149 pruned. Trial was pruned at iteration 4.
# [I 2025-03-26 17:10:24,509] Trial 150 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:24,684] Trial 151 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:24,856] Trial 152 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:25,034] Trial 153 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:25,582] Trial 154 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:10:25,759] Trial 155 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:25,957] Trial 156 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:26,148] Trial 157 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:26,324] Trial 158 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:26,502] Trial 159 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:26,675] Trial 160 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:29,636] Trial 161 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:29,835] Trial 162 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:10:30,026] Trial 163 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:10:31,798] Trial 164 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:10:33,109] Trial 165 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:10:34,116] Trial 166 pruned. Trial was pruned at iteration 38.
# [I 2025-03-26 17:10:34,628] Trial 167 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:10:35,665] Trial 168 pruned. Trial was pruned at iteration 36.
# [I 2025-03-26 17:10:35,873] Trial 169 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:36,211] Trial 170 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:10:39,230] Trial 171 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:42,504] Trial 172 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:43,435] Trial 173 pruned. Trial was pruned at iteration 36.
# [I 2025-03-26 17:10:43,627] Trial 174 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:44,262] Trial 175 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:10:44,484] Trial 176 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:10:46,114] Trial 177 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:10:46,309] Trial 178 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:46,918] Trial 179 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:10:47,125] Trial 180 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:47,333] Trial 181 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:51,497] Trial 182 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:56,300] Trial 183 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:10:57,229] Trial 184 pruned. Trial was pruned at iteration 36.
# [I 2025-03-26 17:10:57,502] Trial 185 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:57,688] Trial 186 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:10:59,372] Trial 187 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:10:59,785] Trial 188 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:10:59,944] Trial 189 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:00,114] Trial 190 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:11:00,315] Trial 191 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:11:00,489] Trial 192 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:00,650] Trial 193 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:09,453] Trial 194 pruned. Trial was pruned at iteration 308.
# [I 2025-03-26 17:11:11,878] Trial 195 pruned. Trial was pruned at iteration 102.
# [I 2025-03-26 17:11:12,444] Trial 196 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:11:14,110] Trial 197 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:11:14,607] Trial 198 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:11:19,004] Trial 199 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:11:20,471] Trial 200 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:11:22,311] Trial 201 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:11:22,554] Trial 202 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:11:23,556] Trial 203 pruned. Trial was pruned at iteration 38.
# [I 2025-03-26 17:11:23,758] Trial 204 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:24,348] Trial 205 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:11:26,709] Trial 206 pruned. Trial was pruned at iteration 89.
# [I 2025-03-26 17:11:26,951] Trial 207 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:11:27,179] Trial 208 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:27,386] Trial 209 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:28,661] Trial 210 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:11:29,759] Trial 211 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:11:29,947] Trial 212 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:30,147] Trial 213 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:31,292] Trial 214 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:11:50,808] Trial 215 finished with value: 0.8652635051188952 and parameters: {'n_estimators': 1100, 'learning_rate': 0.023259109811244575, 'num_leaves': 41, 'max_depth': 6, 'reg_alpha': 0.014864885389253115, 'reg_lambda': 0.28955549506306727, 'colsample_bytree': 0.7509838340518603, 'subsample': 0.6592497687669507, 'subsample_freq': 1, 'min_child_samples': 20}. Best is trial 136 with value: 0.8653692057285397.
# [I 2025-03-26 17:11:51,100] Trial 216 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:11:56,200] Trial 217 pruned. Trial was pruned at iteration 210.
# [I 2025-03-26 17:11:58,230] Trial 218 pruned. Trial was pruned at iteration 102.
# [I 2025-03-26 17:11:58,433] Trial 219 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:11:58,611] Trial 220 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:11:59,557] Trial 221 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:12:00,478] Trial 222 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:12:04,559] Trial 223 pruned. Trial was pruned at iteration 160.
# [I 2025-03-26 17:12:05,941] Trial 224 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:12:06,134] Trial 225 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:06,447] Trial 226 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:06,935] Trial 227 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:12:07,137] Trial 228 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:07,608] Trial 229 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:12:07,796] Trial 230 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:08,868] Trial 231 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:12:11,717] Trial 232 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:12:12,501] Trial 233 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:12:12,672] Trial 234 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:12,866] Trial 235 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:13,906] Trial 236 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:12:33,825] Trial 237 finished with value: 0.8639842628887326 and parameters: {'n_estimators': 1000, 'learning_rate': 0.023033347689279636, 'num_leaves': 44, 'max_depth': 7, 'reg_alpha': 0.0069649501636793575, 'reg_lambda': 0.02311788443006403, 'colsample_bytree': 0.811941193288454, 'subsample': 0.8827378177755388, 'subsample_freq': 1, 'min_child_samples': 53}. Best is trial 136 with value: 0.8653692057285397.
# [I 2025-03-26 17:12:34,223] Trial 238 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:12:35,623] Trial 239 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:12:35,794] Trial 240 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:36,600] Trial 241 pruned. Trial was pruned at iteration 39.
# [I 2025-03-26 17:12:38,143] Trial 242 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:12:38,921] Trial 243 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:12:40,813] Trial 244 pruned. Trial was pruned at iteration 94.
# [I 2025-03-26 17:12:41,600] Trial 245 pruned. Trial was pruned at iteration 39.
# [I 2025-03-26 17:12:41,805] Trial 246 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:42,250] Trial 247 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:12:42,444] Trial 248 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:42,624] Trial 249 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:43,032] Trial 250 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:12:43,218] Trial 251 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:43,731] Trial 252 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:12:43,935] Trial 253 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:44,173] Trial 254 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:44,357] Trial 255 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:44,688] Trial 256 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:45,135] Trial 257 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:12:45,343] Trial 258 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:45,826] Trial 259 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:12:46,011] Trial 260 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:46,371] Trial 261 pruned. Trial was pruned at iteration 8.
# [I 2025-03-26 17:12:46,574] Trial 262 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:46,773] Trial 263 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:46,947] Trial 264 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:47,160] Trial 265 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:47,352] Trial 266 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:47,618] Trial 267 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:12:47,825] Trial 268 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:50,480] Trial 269 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:12:50,693] Trial 270 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:50,890] Trial 271 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:51,082] Trial 272 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:51,267] Trial 273 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:51,463] Trial 274 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:51,769] Trial 275 pruned. Trial was pruned at iteration 8.
# [I 2025-03-26 17:12:52,208] Trial 276 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:12:52,402] Trial 277 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:52,602] Trial 278 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:55,290] Trial 279 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:12:55,489] Trial 280 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:56,265] Trial 281 pruned. Trial was pruned at iteration 37.
# [I 2025-03-26 17:12:56,469] Trial 282 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:56,649] Trial 283 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:57,232] Trial 284 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:12:57,436] Trial 285 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:58,111] Trial 286 pruned. Trial was pruned at iteration 32.
# [I 2025-03-26 17:12:58,545] Trial 287 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:12:58,726] Trial 288 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:59,165] Trial 289 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:12:59,380] Trial 290 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:12:59,942] Trial 291 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:13:00,156] Trial 292 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:13:00,345] Trial 293 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:00,541] Trial 294 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:00,724] Trial 295 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:00,910] Trial 296 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:01,350] Trial 297 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:13:01,558] Trial 298 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:01,768] Trial 299 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:02,722] Trial 300 pruned. Trial was pruned at iteration 39.
# [I 2025-03-26 17:13:02,907] Trial 301 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:03,093] Trial 302 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:03,504] Trial 303 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:13:04,010] Trial 304 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:13:04,199] Trial 305 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:07,802] Trial 306 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:10,048] Trial 307 pruned. Trial was pruned at iteration 116.
# [I 2025-03-26 17:13:13,800] Trial 308 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:17,626] Trial 309 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:21,164] Trial 310 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:24,809] Trial 311 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:29,443] Trial 312 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:29,636] Trial 313 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:29,896] Trial 314 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:13:33,488] Trial 315 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:33,707] Trial 316 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:34,168] Trial 317 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:13:34,364] Trial 318 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:38,119] Trial 319 pruned. Trial was pruned at iteration 140.
# [I 2025-03-26 17:13:38,326] Trial 320 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:38,523] Trial 321 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:38,999] Trial 322 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:13:39,261] Trial 323 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:39,467] Trial 324 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:39,860] Trial 325 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:13:40,061] Trial 326 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:40,254] Trial 327 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:40,634] Trial 328 pruned. Trial was pruned at iteration 12.
# [I 2025-03-26 17:13:40,835] Trial 329 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:41,022] Trial 330 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:41,222] Trial 331 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:13:41,796] Trial 332 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:14:02,236] Trial 333 finished with value: 0.8639736687501806 and parameters: {'n_estimators': 1000, 'learning_rate': 0.012042031432623833, 'num_leaves': 37, 'max_depth': 7, 'reg_alpha': 0.8966450341634854, 'reg_lambda': 0.025548341409185084, 'colsample_bytree': 0.7707329451843415, 'subsample': 0.44528516587795525, 'subsample_freq': 1, 'min_child_samples': 28}. Best is trial 136 with value: 0.8653692057285397.
# [I 2025-03-26 17:14:02,532] Trial 334 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:02,728] Trial 335 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:02,913] Trial 336 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:03,118] Trial 337 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:03,666] Trial 338 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:14:04,135] Trial 339 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:14:04,334] Trial 340 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:04,530] Trial 341 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:04,731] Trial 342 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:05,230] Trial 343 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:14:05,433] Trial 344 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:06,000] Trial 345 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:14:06,239] Trial 346 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:06,537] Trial 347 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:06,728] Trial 348 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:07,000] Trial 349 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:07,186] Trial 350 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:08,270] Trial 351 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:14:08,498] Trial 352 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:08,698] Trial 353 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:08,920] Trial 354 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:09,122] Trial 355 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:09,357] Trial 356 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:09,570] Trial 357 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:10,066] Trial 358 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:14:10,298] Trial 359 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:10,512] Trial 360 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:10,781] Trial 361 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:10,974] Trial 362 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:11,844] Trial 363 pruned. Trial was pruned at iteration 38.
# [I 2025-03-26 17:14:12,152] Trial 364 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:12,399] Trial 365 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:13,367] Trial 366 pruned. Trial was pruned at iteration 42.
# [I 2025-03-26 17:14:13,834] Trial 367 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:14:15,519] Trial 368 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:14:15,730] Trial 369 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:15,999] Trial 370 pruned. Trial was pruned at iteration 4.
# [I 2025-03-26 17:14:16,197] Trial 371 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:16,407] Trial 372 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:17,053] Trial 373 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:14:17,273] Trial 374 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:17,651] Trial 375 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:17,835] Trial 376 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:18,788] Trial 377 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:14:19,051] Trial 378 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:19,491] Trial 379 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:19,750] Trial 380 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:20,024] Trial 381 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:20,674] Trial 382 pruned. Trial was pruned at iteration 16.
# [I 2025-03-26 17:14:20,947] Trial 383 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:21,319] Trial 384 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:21,690] Trial 385 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:21,970] Trial 386 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:22,229] Trial 387 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:22,474] Trial 388 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:22,837] Trial 389 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:24,821] Trial 390 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:14:25,019] Trial 391 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:25,317] Trial 392 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:25,514] Trial 393 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:25,709] Trial 394 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:25,921] Trial 395 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:37,064] Trial 396 finished with value: 0.863979206595333 and parameters: {'n_estimators': 4300, 'learning_rate': 0.022120692302497292, 'num_leaves': 67, 'max_depth': 7, 'reg_alpha': 0.49130733531630677, 'reg_lambda': 0.0029510826934621304, 'colsample_bytree': 0.7646105657365381, 'subsample': 0.4475056211699921, 'subsample_freq': 1, 'min_child_samples': 26}. Best is trial 136 with value: 0.8653692057285397.
# [I 2025-03-26 17:14:37,291] Trial 397 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:37,492] Trial 398 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:39,210] Trial 399 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:14:39,423] Trial 400 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:39,598] Trial 401 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:39,768] Trial 402 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:40,251] Trial 403 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:40,497] Trial 404 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:40,759] Trial 405 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:40,991] Trial 406 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:41,184] Trial 407 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:41,408] Trial 408 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:41,607] Trial 409 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:41,836] Trial 410 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:42,136] Trial 411 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:42,388] Trial 412 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:42,632] Trial 413 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:42,844] Trial 414 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:43,038] Trial 415 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:43,437] Trial 416 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:43,632] Trial 417 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:43,816] Trial 418 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:44,024] Trial 419 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:44,502] Trial 420 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:14:44,788] Trial 421 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:45,031] Trial 422 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:45,248] Trial 423 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:45,470] Trial 424 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:45,671] Trial 425 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:45,877] Trial 426 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:46,062] Trial 427 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:46,586] Trial 428 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:14:46,760] Trial 429 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:50,256] Trial 430 pruned. Trial was pruned at iteration 130.
# [I 2025-03-26 17:14:50,689] Trial 431 pruned. Trial was pruned at iteration 14.
# [I 2025-03-26 17:14:50,879] Trial 432 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:51,051] Trial 433 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:51,272] Trial 434 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:51,542] Trial 435 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:51,769] Trial 436 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:51,959] Trial 437 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:52,155] Trial 438 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:14:52,369] Trial 439 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:14:52,640] Trial 440 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:14:57,995] Trial 441 pruned. Trial was pruned at iteration 160.
# [I 2025-03-26 17:14:58,422] Trial 442 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:00,282] Trial 443 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:15:06,529] Trial 444 pruned. Trial was pruned at iteration 160.
# [I 2025-03-26 17:15:08,153] Trial 445 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:15:08,406] Trial 446 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:08,589] Trial 447 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:08,770] Trial 448 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:09,067] Trial 449 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:09,251] Trial 450 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:09,491] Trial 451 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:09,676] Trial 452 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:09,856] Trial 453 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:10,250] Trial 454 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:10,463] Trial 455 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:10,664] Trial 456 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:10,904] Trial 457 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:11,090] Trial 458 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:11,415] Trial 459 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:11,682] Trial 460 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:12,793] Trial 461 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:15:12,987] Trial 462 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:13,190] Trial 463 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:13,501] Trial 464 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:13,688] Trial 465 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:14,169] Trial 466 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:14,372] Trial 467 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:20,740] Trial 468 pruned. Trial was pruned at iteration 155.
# [I 2025-03-26 17:15:21,214] Trial 469 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:15:21,624] Trial 470 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:15:22,396] Trial 471 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:15:22,620] Trial 472 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:22,943] Trial 473 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:24,700] Trial 474 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:15:29,120] Trial 475 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:15:29,371] Trial 476 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:29,808] Trial 477 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:30,105] Trial 478 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:30,876] Trial 479 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:15:31,928] Trial 480 pruned. Trial was pruned at iteration 20.
# [I 2025-03-26 17:15:32,246] Trial 481 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:32,952] Trial 482 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:15:33,243] Trial 483 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:33,993] Trial 484 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:34,218] Trial 485 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:34,576] Trial 486 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:34,790] Trial 487 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:34,979] Trial 488 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:35,712] Trial 489 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:15:37,269] Trial 490 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:15:37,522] Trial 491 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:37,700] Trial 492 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:37,877] Trial 493 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:38,044] Trial 494 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:38,213] Trial 495 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:38,480] Trial 496 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:38,717] Trial 497 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:38,915] Trial 498 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:41,861] Trial 499 pruned. Trial was pruned at iteration 126.
# [I 2025-03-26 17:15:42,071] Trial 500 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:42,543] Trial 501 pruned. Trial was pruned at iteration 20.
# [I 2025-03-26 17:15:42,713] Trial 502 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:43,012] Trial 503 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:43,203] Trial 504 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:43,460] Trial 505 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:43,644] Trial 506 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:43,815] Trial 507 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:43,996] Trial 508 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:44,175] Trial 509 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:44,375] Trial 510 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:44,575] Trial 511 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:45,392] Trial 512 pruned. Trial was pruned at iteration 20.
# [I 2025-03-26 17:15:45,587] Trial 513 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:45,766] Trial 514 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:45,935] Trial 515 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:46,138] Trial 516 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:46,315] Trial 517 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:46,492] Trial 518 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:46,674] Trial 519 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:46,867] Trial 520 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:47,333] Trial 521 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:15:47,626] Trial 522 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:47,826] Trial 523 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:48,078] Trial 524 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:15:48,284] Trial 525 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:48,722] Trial 526 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:15:49,108] Trial 527 pruned. Trial was pruned at iteration 14.
# [I 2025-03-26 17:15:49,300] Trial 528 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:49,542] Trial 529 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:49,780] Trial 530 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:49,990] Trial 531 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:50,283] Trial 532 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:50,473] Trial 533 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:50,649] Trial 534 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:50,820] Trial 535 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,004] Trial 536 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,181] Trial 537 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,367] Trial 538 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,547] Trial 539 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,717] Trial 540 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:51,897] Trial 541 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:52,127] Trial 542 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:15:52,322] Trial 543 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:15:52,503] Trial 544 pruned. Trial was pruned at iteration 0.
# ...
# [I 2025-03-26 17:17:39,720] Trial 798 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:39,934] Trial 799 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:40,152] Trial 800 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:17:40,630] Trial 801 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:17:40,960] Trial 802 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:17:41,246] Trial 803 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:17:41,460] Trial 804 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:41,860] Trial 805 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:17:42,102] Trial 806 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:42,310] Trial 807 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:45,566] Trial 808 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:17:45,784] Trial 809 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:46,193] Trial 810 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:17:46,436] Trial 811 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:47,802] Trial 812 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:17:48,282] Trial 813 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:17:48,653] Trial 814 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:17:48,995] Trial 815 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:52,528] Trial 816 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:17:52,746] Trial 817 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:17:53,007] Trial 818 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:17:53,229] Trial 819 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:53,453] Trial 820 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:53,658] Trial 821 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:53,971] Trial 822 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:54,201] Trial 823 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:17:54,421] Trial 824 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:54,618] Trial 825 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:54,847] Trial 826 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:17:56,303] Trial 827 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:17:56,544] Trial 828 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:56,751] Trial 829 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:17:57,936] Trial 830 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:18:02,140] Trial 831 pruned. Trial was pruned at iteration 191.
# [I 2025-03-26 17:18:02,615] Trial 832 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:18:02,834] Trial 833 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:03,103] Trial 834 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:03,318] Trial 835 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:03,610] Trial 836 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:03,829] Trial 837 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:04,146] Trial 838 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:04,418] Trial 839 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:04,620] Trial 840 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:04,823] Trial 841 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:05,089] Trial 842 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:05,508] Trial 843 pruned. Trial was pruned at iteration 15.
# [I 2025-03-26 17:18:05,779] Trial 844 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:05,977] Trial 845 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:06,180] Trial 846 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:06,391] Trial 847 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:06,648] Trial 848 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:07,089] Trial 849 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:18:08,330] Trial 850 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:18:08,552] Trial 851 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:08,831] Trial 852 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:09,176] Trial 853 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:09,413] Trial 854 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:09,605] Trial 855 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:09,809] Trial 856 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:10,011] Trial 857 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:10,402] Trial 858 pruned. Trial was pruned at iteration 14.
# [I 2025-03-26 17:18:10,609] Trial 859 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:10,820] Trial 860 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:11,054] Trial 861 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:11,271] Trial 862 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:11,488] Trial 863 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:11,694] Trial 864 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:11,903] Trial 865 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:12,821] Trial 866 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:18:13,035] Trial 867 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:13,287] Trial 868 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:13,494] Trial 869 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:13,697] Trial 870 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:14,026] Trial 871 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:14,232] Trial 872 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:14,452] Trial 873 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:14,912] Trial 874 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:18:15,203] Trial 875 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:15,478] Trial 876 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:15,707] Trial 877 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:15,923] Trial 878 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:16,228] Trial 879 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:16,714] Trial 880 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:18:16,925] Trial 881 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:17,130] Trial 882 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:18,156] Trial 883 pruned. Trial was pruned at iteration 44.
# [I 2025-03-26 17:18:18,376] Trial 884 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:18,581] Trial 885 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:19,129] Trial 886 pruned. Trial was pruned at iteration 14.
# [I 2025-03-26 17:18:22,660] Trial 887 pruned. Trial was pruned at iteration 134.
# [I 2025-03-26 17:18:23,116] Trial 888 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:18:23,325] Trial 889 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:23,532] Trial 890 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:23,743] Trial 891 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:23,971] Trial 892 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:27,309] Trial 893 pruned. Trial was pruned at iteration 126.
# [I 2025-03-26 17:18:27,548] Trial 894 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:27,806] Trial 895 pruned. Trial was pruned at iteration 4.
# [I 2025-03-26 17:18:28,017] Trial 896 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:28,223] Trial 897 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:28,437] Trial 898 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:28,646] Trial 899 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:28,867] Trial 900 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:29,132] Trial 901 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:29,351] Trial 902 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:29,926] Trial 903 pruned. Trial was pruned at iteration 20.
# [I 2025-03-26 17:18:30,147] Trial 904 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:30,367] Trial 905 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:31,729] Trial 906 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:18:32,016] Trial 907 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:32,227] Trial 908 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:32,446] Trial 909 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:32,652] Trial 910 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:32,878] Trial 911 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:33,151] Trial 912 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:33,362] Trial 913 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:33,712] Trial 914 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:33,932] Trial 915 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:34,157] Trial 916 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:34,721] Trial 917 pruned. Trial was pruned at iteration 18.
# [I 2025-03-26 17:18:34,929] Trial 918 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:36,415] Trial 919 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:18:36,649] Trial 920 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:36,854] Trial 921 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:37,063] Trial 922 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:37,277] Trial 923 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:37,602] Trial 924 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:37,816] Trial 925 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:38,139] Trial 926 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:38,557] Trial 927 pruned. Trial was pruned at iteration 14.
# [I 2025-03-26 17:18:38,769] Trial 928 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:38,982] Trial 929 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:40,682] Trial 930 pruned. Trial was pruned at iteration 82.
# [I 2025-03-26 17:18:40,969] Trial 931 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:41,185] Trial 932 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:41,401] Trial 933 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:41,675] Trial 934 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:41,891] Trial 935 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:42,117] Trial 936 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:42,334] Trial 937 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:43,655] Trial 938 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:18:43,874] Trial 939 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:44,087] Trial 940 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:44,299] Trial 941 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:44,515] Trial 942 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:44,895] Trial 943 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:45,116] Trial 944 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:45,359] Trial 945 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:45,577] Trial 946 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:45,807] Trial 947 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:46,593] Trial 948 pruned. Trial was pruned at iteration 40.
# [I 2025-03-26 17:18:46,812] Trial 949 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:47,075] Trial 950 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:47,297] Trial 951 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:47,522] Trial 952 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:47,805] Trial 953 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:48,283] Trial 954 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:18:48,497] Trial 955 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:48,938] Trial 956 pruned. Trial was pruned at iteration 17.
# [I 2025-03-26 17:18:49,214] Trial 957 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:49,448] Trial 958 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:49,787] Trial 959 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:49,997] Trial 960 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:50,208] Trial 961 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:50,430] Trial 962 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:50,670] Trial 963 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:50,889] Trial 964 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:51,096] Trial 965 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:51,363] Trial 966 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:52,687] Trial 967 pruned. Trial was pruned at iteration 72.
# [I 2025-03-26 17:18:52,964] Trial 968 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:53,246] Trial 969 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:53,461] Trial 970 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:53,733] Trial 971 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:55,130] Trial 972 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:18:55,350] Trial 973 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:55,631] Trial 974 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:55,941] Trial 975 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:56,177] Trial 976 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:56,469] Trial 977 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:57,725] Trial 978 pruned. Trial was pruned at iteration 70.
# [I 2025-03-26 17:18:57,962] Trial 979 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:58,304] Trial 980 pruned. Trial was pruned at iteration 5.
# [I 2025-03-26 17:18:58,529] Trial 981 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:58,748] Trial 982 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:58,958] Trial 983 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:59,178] Trial 984 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:59,389] Trial 985 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:18:59,614] Trial 986 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:18:59,828] Trial 987 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:00,449] Trial 988 pruned. Trial was pruned at iteration 13.
# [I 2025-03-26 17:19:00,668] Trial 989 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:00,896] Trial 990 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:01,119] Trial 991 pruned. Trial was pruned at iteration 1.
# [I 2025-03-26 17:19:01,635] Trial 992 pruned. Trial was pruned at iteration 20.
# [I 2025-03-26 17:19:01,860] Trial 993 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:02,074] Trial 994 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:02,292] Trial 995 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:02,539] Trial 996 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:03,054] Trial 997 pruned. Trial was pruned at iteration 19.
# [I 2025-03-26 17:19:03,280] Trial 998 pruned. Trial was pruned at iteration 0.
# [I 2025-03-26 17:19:03,498] Trial 999 pruned. Trial was pruned at iteration 0.

# %%
print("\n--- Результаты оптимизации Optuna ---")
print(f"Количество завершенных испытаний: {len(study.trials)}")

best_trial = study.best_trial
print(f"Лучшее испытание (Trial {best_trial.number}):")
print(f"  Value (ROC AUC на CV): {best_trial.value:.5f}")
print("  Best Parameters:")
for key, value in best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# --- Результаты оптимизации Optuna ---
# Количество завершенных испытаний: 1000
# Лучшее испытание (Trial 136):
#   Value (ROC AUC на CV): 0.86537
#   Best Parameters:
#     n_estimators: 4400
#     learning_rate: 0.0231336496056604
#     num_leaves: 21
#     max_depth: 7
#     reg_alpha: 0.013084385071543842
#     reg_lambda: 0.40470051985952027
#     colsample_bytree: 0.7837665479281083
#     subsample: 0.8341784879213847
#     subsample_freq: 4
#     min_child_samples: 34

# %%
best_params = best_trial.params

best_params['objective'] = 'binary'
best_params['metric'] = 'auc'
best_params['boosting_type'] = 'gbdt'
best_params['random_state'] = RANDOM_SEED
best_params['n_jobs'] = -1
best_params['class_weight'] = 'balanced'

# %%
print("\n--- Обучение финальной модели LightGBM с лучшими параметрами ---")

final_model = lgb.LGBMClassifier(**best_params)

final_model.fit(X_train, y_train)

print("Финальная модель обучена.")
# Out:
# --- Обучение финальной модели LightGBM с лучшими параметрами ---
# Финальная модель обучена.

# %%
print(f"\n--- Сохранение финальной модели в {MODEL_PATH} ---")
try:
    joblib.dump(final_model, MODEL_PATH)
    print("Модель успешно сохранена.")
except Exception as e:
    print(f"Ошибка при сохранении модели: {e}")
# Out:
# --- Сохранение финальной модели в ../models/lgbm_churn_model.joblib ---
# Модель успешно сохранена.

# %%
results_lgbm = evaluate_model(final_model, X_test, y_test, "LightGBM (Optimized)")

print("\n--- Сравнение с Baseline (Logistic Regression) ---")

results_log_reg = {'roc_auc': 0.8443, 'f1_score_1': 0.5547, 'recall_1': 0.7543, 'precision_1': 0.4386, 'pr_auc': 0.6310}

comparison_data = {}
if results_lgbm:
    comparison_data["LightGBM (Optimized)"] = results_lgbm
    
if comparison_data:
    comparison_df = pd.DataFrame(comparison_data).T
    print(comparison_df[['roc_auc', 'pr_auc', 'f1_score_1', 'recall_1', 'precision_1']].round(4))
else:
    print("Не удалось сформировать таблицу сравнения.")
# Out:
# --- Оценка модели: LightGBM (Optimized) ---
# ROC AUC: 0.8303
# PR AUC (Average Precision): 0.6437
# F1 Score (Class 1): 0.5576
# Recall (Class 1): 0.5528
# Precision (Class 1): 0.5625
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Лоялен (0)       0.89      0.89      0.89      1593
#    Отток (1)       0.56      0.55      0.56       407
#
#     accuracy                           0.82      2000
#    macro avg       0.72      0.72      0.72      2000
# weighted avg       0.82      0.82      0.82      2000
#
# Confusion Matrix:
# [[1418  175]
#  [ 182  225]]
#
# --- Сравнение с Baseline (Logistic Regression) ---
#                       roc_auc  pr_auc  f1_score_1  recall_1  precision_1
# LightGBM (Optimized)   0.8303  0.6437      0.5576    0.5528       0.5625

# %%
print("\n--- Optuna Dashboard ---")
print("Оптимизация завершена или прервана.")
print("\nНаходясь в директории проекта, выполните команду:")
print(f"optuna-dashboard {OPTUNA_DB_URL}")
# Out:
# --- Optuna Dashboard ---
# Оптимизация завершена или прервана.
#
# Находясь в директории проекта, выполните команду:
# optuna-dashboard sqlite:///optuna_lgbm_churn.db
